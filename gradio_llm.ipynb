# %%
# !pip install -q google-generativeai gradio

# %%
from google.colab import userdata
import google.generativeai as genai

# Get API key from Colab Secrets
API_KEY = userdata.get("GEMINI_API_KEY")

print("API KEY FOUND:", API_KEY is not None)

if not API_KEY:
    raise ValueError("❌ GEMINI_API_KEY not found in Colab Secrets!")

# Configure Gemini
genai.configure(api_key=API_KEY)

# Load model
model = genai.GenerativeModel("models/gemini-1.5-flash")

print("✅ Gemini configured successfully!")
# Out:
# API KEY FOUND: True
# ✅ Gemini configured successfully!

# %%
def chat_with_gemini(user_message):
    response = model.generate_content(user_message)
    return response.text

# %%
import gradio as gr

with gr.Blocks() as demo:
    gr.Markdown("# 🤖 Gemini Chatbot (Colab)")

    chatbot = gr.Chatbot()
    msg = gr.Textbox(label="Your Message")
    clear = gr.Button("Clear")

    def respond(message, history):
        reply = chat_with_gemini(message)
        history.append((message, reply))
        return "", history

    msg.submit(respond, [msg, chatbot], [msg, chatbot])
    clear.click(lambda: [], None, chatbot)

demo.launch()
# Out:
# /tmp/ipython-input-220425569.py:6: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot()
# /tmp/ipython-input-220425569.py:6: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot()
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://5562dbf505aab1bf42.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://5562dbf505aab1bf42.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
